# %%
from datasets import load_dataset, Dataset
from ragas import evaluate
from ragas.metrics import context_recall, context_precision, answer_correctness
from src.retriever import get_relevant_chunks
import os
# Out:
# d:\RagGpt\src\retriever.py:13: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   _embeddings = HuggingFaceEmbeddings(model_name=settings.EMBEDDING_MODEL)

# %%
hotpot = load_dataset("hotpot_qa", "distractor", split="validation[:700]")
hotpot = hotpot.filter(lambda x: x["answer"].strip().lower() not in ["yes","no"])

# %%
len(hotpot)
# Out:
# 658

# %%
questions = hotpot["question"]
ground_truths = hotpot["answer"]       # 正确答案
contexts_block = hotpot["context"]      # dict，有 title & sentences

# %%
#把每个 title+sentences 拼成一个段落，写入 documents/hotpot/*.txt
out_dir = "documents/hotpot"
os.makedirs(out_dir, exist_ok=True)

paras = []  # [(title, paragraph_str), ...]
for block in contexts_block:
    for title, sents in zip(block["title"], block["sentences"]):
        para = " ".join(sents).strip()
        paras.append((title, para))

# 去重
seen, uniq = set(), []
for title, para in paras:
    if para not in seen:
        seen.add(para)
        uniq.append((title, para))

for i, (title, para) in enumerate(uniq):
    safe = "".join(c if c.isalnum() else "_" for c in title)[:30]
    fname = f"{i:04d}_{safe}.txt"
    with open(f"{out_dir}/{fname}", "w", encoding="utf-8") as f:
        f.write(para)

print(f"Wrote {len(uniq)} paragraphs to {out_dir}")
# Out:
# Wrote 6480 paragraphs to documents/hotpot

# %%
#手搓 Top-k 检索 
contexts_list, manual_hits = [], []

for i, (q, gt) in enumerate(zip(questions, ground_truths)):
    ctxs = get_relevant_chunks(q, k=7)   # 设置k
    contexts_list.append(ctxs)
    hit = any(gt in c for c in ctxs)
    manual_hits.append(hit)
    print(f"[{i:02d}] hit={hit}  retrieved={len(ctxs)}")

print(f"\nManual Recall: {sum(manual_hits)/len(manual_hits):.3f}")
# Out:
# [Retriever] Intersection (交集) count: 8
# [00] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 32
# [01] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 10
# [02] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 40
# [03] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 11
# [04] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 22
# [05] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 16
# [06] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 34
# [07] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 19
# [08] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 23
# [09] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 29
# [10] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 18
# [11] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 36
# [12] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 32
# [13] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 23
# [14] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 43
# [15] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 12
# [16] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 42
# [17] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 16
# [18] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 13
# [19] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 15
# [20] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 49
# [21] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 22
# [22] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 14
# [23] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 9
# [24] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 13
# [25] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 28
# [26] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 15
# [27] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 28
# [28] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 23
# [29] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 33
# [30] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 24
# [31] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 30
# [32] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 12
# [33] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 37
# [34] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 12
# [35] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 24
# [36] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 22
# [37] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 13
# [38] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 29
# [39] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 26
# [40] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 37
# [41] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 24
# [42] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 41
# [43] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 25
# [44] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 34
# [45] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 33
# [46] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 9
# [47] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 12
# [48] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 28
# [49] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 41
# [50] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 16
# [51] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 8
# [52] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 21
# [53] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 6
# [54] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 16
# [55] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 30
# [56] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 16
# [57] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 14
# [58] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 20
# [59] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 42
# [60] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 16
# [61] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 35
# [62] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 27
# [63] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 12
# [64] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 20
# [65] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 4
# [66] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 14
# [67] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 16
# [68] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 28
# [69] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 28
# [70] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 13
# [71] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 26
# [72] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 40
# [73] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 9
# [74] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 30
# [75] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 12
# [76] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 30
# [77] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 18
# [78] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 8
# [79] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 11
# [80] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 19
# [81] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 28
# [82] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 15
# [83] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 22
# [84] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 11
# [85] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 9
# [86] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 24
# [87] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 22
# [88] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 20
# [89] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 32
# [90] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 52
# [91] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 32
# [92] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 15
#
hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 23
# [531] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 25
# [532] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 36
# [533] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 29
# [534] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 23
# [535] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 39
# [536] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 46
# [537] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 38
# [538] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 19
# [539] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 36
# [540] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 11
# [541] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 30
# [542] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 9
# [543] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 40
# [544] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 32
# [545] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 19
# [546] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 10
# [547] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 5
# [548] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 2
# [549] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 29
# [550] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 28
# [551] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 23
# [552] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 2
# [553] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 11
# [554] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 33
# [555] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 26
# [556] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 12
# [557] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 15
# [558] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 12
# [559] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 28
# [560] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 10
# [561] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 19
# [562] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 11
# [563] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 32
# [564] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 30
# [565] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 21
# [566] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 12
# [567] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 11
# [568] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 37
# [569] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 19
# [570] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 27
# [571] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 26
# [572] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 36
# [573] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 29
# [574] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 13
# [575] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 15
# [576] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 39
# [577] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 12
# [578] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 20
# [579] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 21
# [580] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 45
# [581] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 13
# [582] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 2
# [583] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 42
# [584] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 19
# [585] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 11
# [586] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 8
# [587] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 21
# [588] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 37
# [589] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 22
# [590] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 27
# [591] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 9
# [592] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 25
# [593] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 15
# [594] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 34
# [595] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 7
# [596] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 13
# [597] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 27
# [598] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 20
# [599] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 41
# [600] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 17
# [601] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 8
# [602] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 8
# [603] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 22
# [604] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 36
# [605] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 12
# [606] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 12
# [607] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 11
# [608] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 17
# [609] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 21
# [610] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 13
# [611] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 43
# [612] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 22
# [613] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 21
# [614] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 11
# [615] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 38
# [616] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 23
# [617] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 13
# [618] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 11
# [619] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 27
# [620] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 5
# [621] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 16
# [622] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 17
# [623] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 47
# [624] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 14
# [625] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 11
# [626] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 13
# [627] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 15
# [628] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 22
# [629] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 7
# [630] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 23
# [631] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 38
# [632] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 14
# [633] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 10
# [634] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 20
# [635] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 33
# [636] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 22
# [637] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 17
# [638] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 27
# [639] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 18
# [640] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 6
# [641] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 9
# [642] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 20
# [643] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 8
# [644] hit=False  retrieved=7
# [Retriever] Intersection (交集) count: 31
# [645] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 37
# [646] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 17
# [647] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 23
# [648] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 10
# [649] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 40
# [650] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 15
# [651] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 16
# [652] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 25
# [653] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 50
# [654] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 29
# [655] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 3
# [656] hit=True  retrieved=7
# [Retriever] Intersection (交集) count: 16
# [657] hit=True  retrieved=7
#
# Manual Recall: 0.666

# %%
answers = [" ".join(c) for c in contexts_list]  # 或替换为真实的 LLM 生成

# %%
from ragas.llms import LangchainLLMWrapper
from langchain_openai import ChatOpenAI
from config import settings
#  组装 RAGAS 数据并评估

data = {
    "question":     questions,
    "contexts":     contexts_list,
    #"answer":       answers,
    "ground_truth": ground_truths,
}
print("Data lengths:", {k: len(v) for k, v in data.items()})

eval_ds = Dataset.from_dict(data)
scores  = evaluate(
    dataset=eval_ds,
    metrics=[context_recall, context_precision],
    llm = LangchainLLMWrapper(ChatOpenAI(model=settings.CHAT_MODEL))
)
df = scores.to_pandas()

print("\n=== RAGAS 评估结果 ===")
print(df)

avg = df[["context_recall","context_precision"]].mean()
print("\n=== 平均指标 ===")
print(avg.to_string())
# Out:
# Data lengths: {'question': 658, 'contexts': 658, 'ground_truth': 658}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 19
#      13 print("Data lengths:", {k: len(v) for k, v in data.items()})
#      15 eval_ds = Dataset.from_dict(data)
#      16 scores  = evaluate(
#      17     dataset=eval_ds,
#      18     metrics=[context_recall, context_precision],
# ---> 19     llm = LangchainLLMWrapper(ChatOpenAI(model=settings.CHAT_MODEL))
#      20 )
#      21 df = scores.to_pandas()
#      23 print("\n=== RAGAS 评估结果 ===")
#
# NameError: name 'ChatOpenAI' is not defined

# %%
#  查看第n个样例
n = 0
print(f"--- Sample {n} ---")
print("Q :", questions[n])
print("GT:", ground_truths[n])
print("Ctxs:")
for j, c in enumerate(contexts_list[n]):
    print(f"  ({j})", c[:1000], "…")
print("\nAns:", answers[n])
# Out:
# --- Sample 0 ---
# Q : What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?
# GT: Chief of Protocol
# Ctxs:
#   (0) Kiss and Tell is a 1945 American comedy film starring then 17-year-old Shirley Temple as Corliss Archer.  In the film, two teenage girls cause their respective parents much concern when they start to …
#   (1) role as well as her final film appearance.  It is a sequel to the 1945 film "Kiss and Tell".  "A Kiss for Corliss" was retitled "Almost a Bride" before release and this title appears in the title …
#   (2) A Kiss for Corliss is a 1949 American comedy film directed by Richard Wallace and written by Howard Dimsdale.  It stars Shirley Temple in her final starring role as well as her final film appearance. …
#   (3) Nancy in "Shazzan", Penelope Pitstop, and Josie in "Josie and the Pussycats", and on radio as the title character in "Meet Corliss Archer". …
#   (4) Meet Corliss Archer is an American television sitcom that aired on CBS (July 13, 1951 - August 10, 1951) and in syndication via the Ziv Company from April to December 1954.  The program was an …
#   (5) Meet Corliss Archer, a program from radio's Golden Age, ran from January 7, 1943 to September 30, 1956.  Although it was CBS's answer to NBC's popular "A Date with Judy", it was also broadcast by NBC …
#   (6) during the 1950s, including "Meet Corliss Archer" (1954), "Science Fiction Theatre" (1955–56), and "Highway Patrol" (1955–57).  In the late 1950s and early 1960s he was one of the main editors on …
#
# Ans: Kiss and Tell is a 1945 American comedy film starring then 17-year-old Shirley Temple as Corliss Archer.  In the film, two teenage girls cause their respective parents much concern when they start to role as well as her final film appearance.  It is a sequel to the 1945 film "Kiss and Tell".  "A Kiss for Corliss" was retitled "Almost a Bride" before release and this title appears in the title A Kiss for Corliss is a 1949 American comedy film directed by Richard Wallace and written by Howard Dimsdale.  It stars Shirley Temple in her final starring role as well as her final film appearance. Nancy in "Shazzan", Penelope Pitstop, and Josie in "Josie and the Pussycats", and on radio as the title character in "Meet Corliss Archer". Meet Corliss Archer is an American television sitcom that aired on CBS (July 13, 1951 - August 10, 1951) and in syndication via the Ziv Company from April to December 1954.  The program was an Meet Corliss Archer, a program from radio's Golden Age, ran from January 7, 1943 to September 30, 1956.  Although it was CBS's answer to NBC's popular "A Date with Judy", it was also broadcast by NBC during the 1950s, including "Meet Corliss Archer" (1954), "Science Fiction Theatre" (1955–56), and "Highway Patrol" (1955–57).  In the late 1950s and early 1960s he was one of the main editors on

# %% [markdown]
# sample0是一个典型的 2-Hop 问答。
# 我们检索到了多条 “Kiss and Tell / Meet Corliss Archer”电影和角色有关的信息，
# 但缺少了 Shirley Temple 的政府职务。
# 要答对，必须先命中 Shirley Temple 的人物条目，再从条目里捞到她的政府履历。检索必须跨文档联结电影 → 人物 → 职位。
#
# 解决：
# 1.改写query，多路召回，比如LangChain MultiQueryRetriever
# 2.agent rag，让 Agent 边检索边思考：Step-1 找演员 -》 Step-2 找职位 -》 汇总
# 2.Graph，把文档主动转成“实体-关系图”再检索，适用于多跳。目前只有一跳，不一定要用。且查询成本很大。
