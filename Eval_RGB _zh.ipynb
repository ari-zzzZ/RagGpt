# %%
from datasets import load_dataset, Dataset
from ragas import evaluate
from ragas.metrics import context_recall, context_precision, answer_correctness
from src.retriever import get_relevant_chunks
import os, itertools
# Out:
# d:\projects\RagGpt\src\retriever.py:13: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   _embeddings = HuggingFaceEmbeddings(model_name=settings.EMBEDDING_MODEL)

# %%
ds = load_dataset("AndrewTsai0406/RGB_zh",split="train")
#hotpot = hotpot.filter(lambda x: x["answer"].strip().lower() not in ["yes","no"])

# %%
ds[2]["query"]
# Out:
# '第七届香港立法会议员宣誓仪式的时间'

# %%
questions = ds["query"]
ground_truths = ds["answer"]       
contexts_block = [
    pos + neg                 # 把当前样本中的positive和negative两段列表拼起来
    for pos, neg in zip(ds["positive"], ds["negative"])
]

# %%
import ast   # 用 ast.literal_eval 比 eval 安全

def clean_answer(ans):
    """
    把像 "['12人']" 这样的字符串 → '12人'
    如果本来就是普通字符串，则原样返回
    """
    if isinstance(ans, str) and ans.startswith('[') and ans.endswith(']'):
        try:
            return ast.literal_eval(ans)[0]   # 解析成列表后取第 0 个元素
        except Exception:
            return ans
    return ans

# ds["answer"] 是 list，用列表推导逐个清洗
ground_truths = [clean_answer(a) for a in ds["answer"]]

# %%
print(ground_truths[99])
# Out:
# 中国

# %%
contexts_block[2]

# %%
len(contexts_block)

# %%
type(contexts_block)

# %%
#save_dir = './documents/RGB_zh'
os.makedirs(save_dir, exist_ok=True)   

# ----------- 写入文件 -----------
for idx, item in enumerate(contexts_block, start=1):
    # 生成文件名：001.txt、002.txt……
    filename = os.path.join(save_dir, f'{idx:03d}.txt')
    
    # 如果 item 不是字符串，先转成字符串；如需做清洗可在这里处理
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(str(item))

print(f' 已写入 {len(contexts_block)} 个文件到 {save_dir}')

# %%
contexts_list, manual_hits = [], []

for i, (q, gt) in enumerate(zip(questions, ground_truths)):
    ctxs = get_relevant_chunks(q, k=3)          # 召回的段落列表
    contexts_list.append(ctxs)

    # 把 gt 统一成 list，方便后面双层 any
    answers = gt if isinstance(gt, list) else [gt]

    # 只要某个答案出现在任意 ctx 里，就算命中
    hit = any(ans in c for ans in answers for c in ctxs)
    manual_hits.append(hit)

    print(f"[{i:02d}] hit={hit}  retrieved={len(ctxs)}\n\n")

print(f"\nManual Recall: {sum(manual_hits)/len(manual_hits):.3f}")
# Out:
# [Retriever] Intersection (交集) count: 24
# [00] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [01] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [02] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [03] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [04] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [05] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [06] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [07] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [08] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [09] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [10] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [11] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [12] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [13] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [14] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [15] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [16] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [17] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [18] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [19] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [20] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [21] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [22] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [23] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [24] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [25] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [26] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [27] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [28] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [29] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [30] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [31] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [32] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [33] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [34] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [35] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [36] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [37] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [38] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [39] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [40] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [41] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [42] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [43] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [44] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [45] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [46] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [47] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [48] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [49] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [50] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [51] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [52] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [53] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [54] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [55] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [56] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [57] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [58] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [59] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [60] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [61] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [62] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 24
# [63] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [64] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [65] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [66] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [67] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [68] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [69] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [70] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [71] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [72] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [73] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [74] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [75] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [76] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [77] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [78] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [79] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [80] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [81] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [82] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [83] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [84] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [85] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [86] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [87] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [88] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [89] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [90] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [91] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [92] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [93] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [94] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [95] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [96] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [97] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [98] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [99] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [100] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [101] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [102] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [103] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [104] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [105] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [106] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [107] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [108] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [109] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [110] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [111] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [112] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [113] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [114] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [115] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [116] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [117] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [118] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [119] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [120] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [121] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [122] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [123] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [124] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [125] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [126] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [127] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [128] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [129] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [130] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [131] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [132] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [133] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [134] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [135] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [136] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [137] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [138] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [139] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [140] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [141] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [142] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [143] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [144] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [145] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [146] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [147] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [148] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [149] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [150] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [151] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [152] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [153] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [154] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [155] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [156] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [157] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [158] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [159] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [160] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [161] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [162] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [163] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [164] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [165] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [166] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [167] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [168] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [169] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [170] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [171] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [172] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [173] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [174] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [175] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [176] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [177] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [178] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [179] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [180] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [181] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [182] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [183] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [184] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [185] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [186] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [187] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [188] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [189] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [190] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [191] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [192] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [193] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [194] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [195] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [196] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [197] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [198] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [199] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [200] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [201] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [202] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [203] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [204] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [205] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [206] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [207] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [208] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [209] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [210] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [211] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [212] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [213] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [214] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [215] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [216] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [217] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [218] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [219] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [220] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [221] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [222] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [223] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [224] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [225] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [226] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [227] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [228] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [229] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [230] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [231] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [232] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [233] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [234] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [235] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [236] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [237] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [238] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [239] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [240] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [241] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [242] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [243] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [244] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [245] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [246] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [247] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [248] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [249] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [250] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [251] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [252] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [253] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [254] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [255] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [256] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [257] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [258] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [259] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [260] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [261] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [262] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [263] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [264] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [265] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [266] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [267] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [268] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [269] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [270] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [271] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [272] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [273] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [274] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [275] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [276] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [277] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [278] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [279] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [280] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [281] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [282] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [283] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [284] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [285] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [286] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [287] hit=False  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [288] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [289] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [290] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [291] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [292] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [293] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [294] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [295] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [296] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [297] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [298] hit=True  retrieved=3
#
#
# [Retriever] Intersection (交集) count: 0
# [299] hit=True  retrieved=3
#
#
#
# Manual Recall: 0.773

# %%
answers = [" ".join(c) for c in contexts_list]  # 或替换为真实的 LLM 生成

# %%
#  查看第n个样例
n = 299
print(f"--- Sample {n} ---")
print("Q :", questions[n])
print("GT:", ground_truths[n])
print("Ctxs:")
for j, c in enumerate(contexts_list[n]):
    print(f"  ({j})", c)
print("\nAns:", answers[n])
# Out:
# --- Sample 299 ---
# Q : 2023年温网女单亚军
# GT: 贾巴尔
# Ctxs:
#   (0) 作为去年打进温网女单决赛的两名姑娘，冠军莱巴金娜和亚军贾巴尔，一个\xa0...', 'Jul 8, 2023 ...
#   (1) 'Jul 8, 2023 ... 今晨，2023年温网结束1场女单焦点战。中国金花白卓璇结束神奇旅程，第2轮只抵抗了45分钟就以2个1-6速败上届亚军贾巴尔，未能更进一步。中国女单温网\xa0...']['2023年温布尔登网球锦标赛女子单打比赛，是2023年温布尔登网球锦标赛的其中一个比赛项目。伊莲娜·莱巴金娜是卫冕冠军，[1]但她在1/4决赛中输给本届亚军昂丝·加博。
#   (2) 'Jul 17, 2023 ... 北京时间7月15日，2023年温网女单决赛，上届亚军、6号种子贾巴尔对阵非种子选手万卓索娃。万卓索娃直落两盘总分2-0横扫贾巴尔，勇夺温网女单冠军，\xa0...', 'Apr 3, 2023 ... 这张看似极为用心的温网海报设计，恰恰因为用心过度，才引发了舆论的强烈不满。 作为去年打进温网女单决赛的两名姑娘，冠军莱巴金娜和亚军贾巴尔，一个\xa0...',
#   (3) 这张看似极为用心的温网海报设计，恰恰因为用心过度，才引发了舆论的强烈不满。  作为去年打进温网女单决赛的两名姑娘，冠军莱巴金娜和亚军贾巴尔，一个占据C位，一个位居次C位。', 'Jul 15, 2023 ... 央视网消息：北京时间7月15日，2023年温网女单决赛，上届亚军、6号种子贾巴尔对阵非种子选手万卓索娃。万卓索娃直落两盘总分2-0横扫贾巴尔，勇夺温网\xa0...', 'Jul
#   (4) @Wimbledon 事实上2023年温网男单决赛的第一盘是由乔科维奇以以6：1拿下，在这看似薑是老的辣的开局表现后，现任球王反而凭藉自己的抗压性与不断进步的球技连追2盘逆转听牌，但是乔科维奇随之在第4盘又用6：3的比数替比赛带来精彩悬念。', '21世纪经济报道记者彭强 北京报道
#
# Ans: 作为去年打进温网女单决赛的两名姑娘，冠军莱巴金娜和亚军贾巴尔，一个\xa0...', 'Jul 8, 2023 ... 'Jul 8, 2023 ... 今晨，2023年温网结束1场女单焦点战。中国金花白卓璇结束神奇旅程，第2轮只抵抗了45分钟就以2个1-6速败上届亚军贾巴尔，未能更进一步。中国女单温网\xa0...']['2023年温布尔登网球锦标赛女子单打比赛，是2023年温布尔登网球锦标赛的其中一个比赛项目。伊莲娜·莱巴金娜是卫冕冠军，[1]但她在1/4决赛中输给本届亚军昂丝·加博。 'Jul 17, 2023 ... 北京时间7月15日，2023年温网女单决赛，上届亚军、6号种子贾巴尔对阵非种子选手万卓索娃。万卓索娃直落两盘总分2-0横扫贾巴尔，勇夺温网女单冠军，\xa0...', 'Apr 3, 2023 ... 这张看似极为用心的温网海报设计，恰恰因为用心过度，才引发了舆论的强烈不满。 作为去年打进温网女单决赛的两名姑娘，冠军莱巴金娜和亚军贾巴尔，一个\xa0...', 这张看似极为用心的温网海报设计，恰恰因为用心过度，才引发了舆论的强烈不满。  作为去年打进温网女单决赛的两名姑娘，冠军莱巴金娜和亚军贾巴尔，一个占据C位，一个位居次C位。', 'Jul 15, 2023 ... 央视网消息：北京时间7月15日，2023年温网女单决赛，上届亚军、6号种子贾巴尔对阵非种子选手万卓索娃。万卓索娃直落两盘总分2-0横扫贾巴尔，勇夺温网\xa0...', 'Jul @Wimbledon 事实上2023年温网男单决赛的第一盘是由乔科维奇以以6：1拿下，在这看似薑是老的辣的开局表现后，现任球王反而凭藉自己的抗压性与不断进步的球技连追2盘逆转听牌，但是乔科维奇随之在第4盘又用6：3的比数替比赛带来精彩悬念。', '21世纪经济报道记者彭强 北京报道

# %% [markdown]
# sample0是一个典型的 2-Hop 问答。
# 我们检索到了多条 “Kiss and Tell / Meet Corliss Archer”电影和角色有关的信息，
# 但缺少了 Shirley Temple 的政府职务。
# 要答对，必须先命中 Shirley Temple 的人物条目，再从条目里捞到她的政府履历。检索必须跨文档联结电影 → 人物 → 职位。
#
# 解决：
# 1.改写query，多路召回，比如LangChain MultiQueryRetriever
# 2.agent rag，让 Agent 边检索边思考：Step-1 找演员 -》 Step-2 找职位 -》 汇总
# 2.Graph，把文档主动转成“实体-关系图”再检索，适用于多跳。目前只有一跳，不一定要用。且查询成本很大。

# %%
from ragas.llms import LangchainLLMWrapper
from langchain_openai import ChatOpenAI
from config import settings
#  组装 RAGAS 数据并评估

data = {
    "question":     questions,
    "contexts":     contexts_list,
    #"answer":       answers,
    "ground_truth": ground_truths,
}
print("Data lengths:", {k: len(v) for k, v in data.items()})

eval_ds = Dataset.from_dict(data)
scores  = evaluate(
    dataset=eval_ds,
    metrics=[context_recall, context_precision],
    llm = LangchainLLMWrapper(ChatOpenAI(model=settings.CHAT_MODEL))
)
df = scores.to_pandas()

print("\n=== RAGAS 评估结果 ===")
print(df)

avg = df[["context_recall","context_precision"]].mean()
print("\n=== 平均指标 ===")
print(avg.to_string())
